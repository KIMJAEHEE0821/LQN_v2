# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
#from LQN_igraph import *
import itertools
from copy import deepcopy
import sympy as sp
from itertools import groupby
import igraph as ig
import hashlib
import pickle
import igraph as ig # .pkl 파일에 igraph 객체가 포함되어 있으므로 로드 시 필요합니다.
import os
from typing import Dict, List, Any # 타입 힌트를 위해 추가 (선택 사항)

# %%
from quantum_state_analysis import *

# %%
# --- 설정 ---
# 결과 파일이 저장된 디렉토리 경로
# main_script.py 실행 시 --output_dir 옵션을 사용했다면 해당 경로를, 아니면 기본값 'results'를 사용합니다.
output_dir = '/Users/jaeheekim/Desktop/SKKU_PHDS/code/canonical_graph/result_of_server/0414'

# 로드할 파일의 파라미터 설정 (main_script.py 실행 시 사용했던 값)
num_system = 4
num_ancilla = 2
graph_type = 0

# 로드할 파일 경로 조합
filename = f'bigraph_result_sys{num_system}_anc{num_ancilla}_type{graph_type}.pkl'
file_path = os.path.join(output_dir, filename)

# --- 파일 로드 ---
loaded_data: Dict[str, List[Any]] = {} # 로드된 데이터를 저장할 변수

print(f"'{file_path}' 파일 로드를 시도합니다...")

try:
    # 파일을 바이너리 읽기 모드('rb')로 엽니다.
    with open(file_path, 'rb') as f:
        # pickle.load() 함수를 사용하여 파일에서 데이터를 로드(역직렬화)합니다.
        loaded_data = pickle.load(f)

    print("파일 로드 완료!")

    # --- 로드된 데이터 확인 (선택 사항) ---
    if loaded_data:
        print(f"로드된 데이터 타입: {type(loaded_data)}")
        num_keys = len(loaded_data)
        print(f"데이터에 포함된 고유 구조 해시 키 개수: {num_keys}")

        # 첫 번째 키와 해당 키에 포함된 고유 그래프 개수 확인
        first_key = list(loaded_data.keys())[0]
        num_graphs_in_first_group = len(loaded_data[first_key])
        print(f"첫 번째 그룹(키: '{first_key[:10]}...')에 포함된 고유 그래프 개수: {num_graphs_in_first_group}")

        # 첫 번째 그래프 정보 확인 (igraph 객체)
        if num_graphs_in_first_group > 0:
            first_graph = loaded_data[first_key][0]
            print(f"첫 번째 그룹의 첫 번째 그래프 타입: {type(first_graph)}")
            if isinstance(first_graph, ig.Graph):
                print(f"그래프 요약: {first_graph.summary()}")

    else:
        print("로드된 데이터가 비어 있습니다.")

except FileNotFoundError:
    print(f"오류: 파일을 찾을 수 없습니다. 경로를 확인하세요: '{file_path}'")
except pickle.UnpicklingError:
    print(f"오류: 파일을 로드하는 중 pickle 오류가 발생했습니다. 파일이 손상되었거나 호환되지 않을 수 있습니다.")
except ImportError as e:
    print(f"오류: 데이터를 로드하는 데 필요한 클래스/모듈을 찾을 수 없습니다: {e}")
    print("특히 'igraph' 라이브러리가 현재 환경에 설치되어 있는지 확인하세요.")
except Exception as e:
    print(f"알 수 없는 오류 발생: {e}")
# Out:
# '/Users/jaeheekim/Desktop/SKKU_PHDS/code/canonical_graph/result_of_server/0414/bigraph_result_sys4_anc2_type0.pkl' 파일 로드를 시도합니다...
# 파일 로드 완료!
# 로드된 데이터 타입: <class 'dict'>
# 데이터에 포함된 고유 구조 해시 키 개수: 575
# 첫 번째 그룹(키: 'f3efd1bb4e...')에 포함된 고유 그래프 개수: 5
# 첫 번째 그룹의 첫 번째 그래프 타입: <class 'igraph.Graph'>
# 그래프 요약: IGRAPH UNW- 12 15 --
# + attr: bipartite (v), category (v), name (v), weight (e)

# %%
total_elements = sum(len(v) for v in loaded_data.values())  # 모든 리스트 요소 개수 합산
print(total_elements)  # 출력: 9
# Out:
# 8876

# %%
# graph_dict contains your dictionary of igraph objects
result_dict = process_graph_dict(loaded_data)

# Accessing results
for hash_key, states in result_dict.items():
    print(f"Hash: {hash_key}")
    for state in states:
        counter, matchings, graph, index = state
        print(f"  State coefficients: {dict(counter)}")
# Out:
# Processing 575 graph groups for quantum states...
# Perfect matching analysis complete. Processed: 5, Valid (met conditions): 5, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 5 unique entries.
# Perfect matching analysis complete. Processed: 5, Valid (met conditions): 5, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 5 unique entries.
# Perfect matching analysis complete. Processed: 28, Valid (met conditions): 28, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 28, Valid (met conditions): 28, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 36, Valid (met conditions): 36, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 28 unique entries.
# Perfect matching analysis complete. Processed: 36, Valid (met conditions): 36, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 28 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 5 duplicate states based on Counter content. Kept 19 unique entries.
# Perfect matching analysis complete. Processed: 42, Valid (met conditions): 42, Errors: 0
# Removed 11 duplicate states based on Counter content. Kept 31 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 9, Valid (met conditions): 9, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 9, Valid (met conditions): 9, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 5 duplicate states based on Counter content. Kept 19 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 9, Valid (met conditions): 9, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 9, Valid (met conditions): 9, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 9, Valid (met conditions): 9, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 3 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 9, Valid (met conditions): 9, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 9 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 5, Valid (met conditions): 5, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 5 unique entries.
# Perfect matching analysis complete. Processed: 5, Valid (met conditions): 5, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 5 unique entries.
# Perfect matching analysis complete. Processed: 5, Valid (met conditions): 5, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 5 unique entries.
# Perfect matching analysis complete. Processed: 42, Valid (met conditions): 42, Errors: 0
# Removed 11 duplicate states based on Counter content. Kept 31 unique entries.
# Perfect matching analysis complete. Processed: 42, Valid (met conditions): 42, Errors: 0
# Removed 11 duplicate states based on Counter content. Kept 31 unique entries.
# Perfect matching analysis complete. Processed: 96, Valid (met conditions): 96, Errors: 0
# Removed 22 duplicate states based on Counter content. Kept 74 unique entries.
# Perfect matching analysis complete. Processed: 96, Valid (met conditions): 96, Errors: 0
# Removed 22 duplicate states based on Counter content. Kept 74 unique entries.
# Perfect matching analysis complete. Processed: 42, Valid (met conditions): 42, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 42 unique entries.
# Perfect matching analysis complete. Processed: 42, Valid (met conditions): 42, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 42 unique entries.
# Perfect matching analysis complete. Processed: 52, Valid (met conditions): 52, Errors: 0
# Removed 9 duplicate states based on Counter content. Kept 43 unique entries.
# Perfect matching analysis complete. Processed: 52, Valid (met conditions): 52, Errors: 0
# Removed 9 duplicate states based on Counter content. Kept 43 unique entries.
# Perfect matching analysis complete. Processed: 64, Valid (met conditions): 64, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 56 unique entries.
# Perfect matching analysis complete. Processed: 64, Valid (met conditions): 64, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 56 unique entries.
# Perfect matching analysis complete. Processed: 64, Valid (met conditions): 64, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 56 unique entries.
# Perfect matching analysis complete. Processed: 64, Valid (met conditions): 64, Errors: 0
# Removed 2 duplicate states based on Counter content. Kept 62 unique entries.
# Perfect matching analysis complete. Processed: 52, Valid (met conditions): 52, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 46 unique entries.
# Perfect matching analysis complete. Processed: 52, Valid (met conditions): 52, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 52 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 24 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 24 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 24 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 8 duplicate states based on Counter content. Kept 24 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 24 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 24 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 20, Valid (met conditions): 20, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 28 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 20, Valid (met conditions): 20, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 20 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 4 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 18, Valid (met conditions): 18, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 18 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 3 duplicate states based on Counter content. Kept 21 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 1 duplicate states based on Counter content. Kept 23 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 1 duplicate states based on Counter content. Kept 23 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 2 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 2 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 0, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 0 unique entries.
# Perfect matching analysis complete. Processed: 18, Valid (met conditions): 18, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 18 unique entries.
# Perfect matching analysis complete. Processed: 24, Valid (met conditions): 24, Errors: 0
# Removed 1 duplicate states based on Counter content. Kept 23 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 2 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 2 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 2 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 12, Valid (met conditions): 12, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 12 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 8, Valid (met conditions): 8, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 6, Valid (met conditions): 6, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 6 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 4, Valid (met conditions): 4, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 4 unique entries.
# Perfect matching analysis complete. Processed: 25, Valid (met conditions): 25, Errors: 0
# Removed 17 duplicate states based on Counter content. Kept 8 unique entries.
# Perfect matching analysis complete. Processed: 80, Valid (met conditions): 80, Errors: 0
# Removed 34 duplicate states based on Counter content. Kept 46 unique entries.
# Perfect matching analysis complete. Processed: 80, Valid (met conditions): 80, Errors: 0
# Removed 30 duplicate states based on Counter content. Kept 50 unique entries.
# Perfect matching analysis complete. Processed: 52, Valid (met conditions): 52, Errors: 0
# Removed 12 duplicate states based on Counter content. Kept 40 unique entries.
# Perfect matching analysis complete. Processed: 96, Valid (met conditions): 96, Errors: 0
# Removed 21 duplicate states based on Counter content. Kept 75 unique entries.
# Perfect matching analysis complete. Processed: 96, Valid (met conditions): 96, Errors: 0
# Removed 20 duplicate states based on Counter content. Kept 76 unique entries.
# Perfect matching analysis complete. Processed: 52, Valid (met conditions): 52, Errors: 0
# Removed 5 duplicate states based on Counter content. Kept 47 unique entries.
# Perfect matching analysis complete. Processed: 80, Valid (met conditions): 80, Errors: 0
# Removed 16 duplicate states based on Counter content. Kept 64 unique entries.
# Perfect matching analysis complete. Processed: 80, Valid (met conditions): 80, Errors: 0
# Removed 10 duplicate states based on Counter content. Kept 70 unique entries.
# Perfect matching analysis complete. Processed: 42, Valid (met conditions): 42, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 42 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 18, Valid (met conditions): 18, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 18 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 18, Valid (met conditions): 18, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 18 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 6 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 32, Valid (met conditions): 32, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 32 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 14, Valid (met conditions): 14, Errors: 0
# Removed 3 duplicate states based on Counter content. Kept 11 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 16 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 10, Valid (met conditions): 10, Errors: 0
# Removed 0 duplicate states based on Counter content. Kept 10 unique entries.
# Perfect matching analysis complete. Processed: 16, Valid (met conditions): 16, Errors: 0
# ...
#   State coefficients: {'010122': 1, '011022': 1, '000122': 2, '000022': 1, '001022': 2, '100122': 2, '100022': 1, '101022': 2}
# Hash: 9abfdae8bbfb8850f2e1240783e9f53ac9f60515c254d1e192dbc2632291693a
#   State coefficients: {'010122': 1, '011022': 1, '100122': 1, '101022': 1}
#   State coefficients: {'010022': 1, '011122': 1, '100022': 1, '101122': 1}
#   State coefficients: {'000022': 1, '001122': 1, '110022': 1, '111122': 1}
#   State coefficients: {'000122': 1, '001022': 1, '110122': 1, '111022': 1}
# Hash: 8e1e2b0015edc33057ed1ee23d8af47ae2a9ec65be168f4c9e08fe9bc0200c3f
#   State coefficients: {'010122': 2, '011022': 1, '011122': 1, '100122': 2, '101022': 1, '101122': 1, '110122': 1, '111022': 1}
#   State coefficients: {'010022': 1, '010122': 1, '011122': 2, '100022': 1, '100122': 1, '101122': 2, '110022': 1, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 1, '100022': 2, '100122': 1, '101122': 1, '110022': 1, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 2, '100022': 1, '100122': 1, '101122': 1, '110022': 1, '111122': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 2, '100122': 1, '100022': 1, '101022': 2, '110122': 1, '111022': 1}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '100122': 1, '100022': 1, '101022': 1, '110122': 1, '111022': 1}
#   State coefficients: {'000022': 1, '000122': 1, '001122': 2, '010022': 1, '011122': 1, '110022': 1, '110122': 1, '111122': 2}
#   State coefficients: {'000022': 2, '000122': 1, '001122': 1, '010022': 1, '011122': 1, '110022': 2, '110122': 1, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 2, '010122': 1, '011022': 1, '110122': 1, '110022': 1, '111022': 2}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 1, '011022': 1, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'000122': 2, '000022': 1, '001022': 2, '010122': 1, '011022': 1, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 2, '000122': 1, '001022': 1, '100122': 1, '100022': 1, '101022': 2}
# Hash: 2239553fef0fbdf687615e73e978ac8c06595f7e7b56c9da932458c776887677
#   State coefficients: {'010122': 2, '011022': 2, '100122': 2, '101022': 2, '110122': 1, '111022': 1}
#   State coefficients: {'010022': 2, '011122': 2, '100022': 2, '101122': 2, '110022': 1, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 2, '100022': 2, '100122': 1, '101122': 2}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '100122': 2, '100022': 1, '101022': 2}
#   State coefficients: {'000022': 2, '001122': 2, '010022': 1, '011122': 1, '110022': 2, '111122': 2}
#   State coefficients: {'000122': 2, '001022': 2, '010122': 1, '011022': 1, '110122': 2, '111022': 2}
#   State coefficients: {'000122': 2, '000022': 1, '001022': 2, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'010122': 2, '011022': 2, '000122': 1, '001022': 1, '100122': 2, '101022': 2}
# Hash: 08518c760d0d0825d549928744ebd6d004bb7c01bd8a5dcb2c51130d2599d7ad
#   State coefficients: {'010122': 2, '011022': 2, '011122': 1, '100122': 2, '101022': 2, '101122': 1, '110122': 1, '111022': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 2, '100022': 2, '100122': 1, '101122': 2, '110022': 1, '111122': 1}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '100122': 2, '100022': 1, '101022': 2, '110122': 1, '111022': 1}
#   State coefficients: {'000022': 2, '000122': 1, '001122': 2, '010022': 1, '011122': 1, '110022': 2, '110122': 1, '111122': 2}
#   State coefficients: {'000122': 2, '000022': 1, '001022': 2, '010122': 1, '011022': 1, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '000122': 1, '001022': 1, '100122': 2, '100022': 1, '101022': 2}
# Hash: 55b256b51661d8ac127e0c13a3e32da52f256a0eecd53ceab23dd283ed29114e
#   State coefficients: {'010122': 1, '011022': 1, '011122': 2, '100122': 1, '101022': 1, '101122': 2, '110122': 1, '111022': 1, '111122': 2}
#   State coefficients: {'010022': 1, '010122': 2, '011122': 1, '100022': 1, '100122': 2, '101122': 1, '110022': 1, '110122': 2, '111122': 1}
#   State coefficients: {'010022': 1, '010122': 1, '011122': 1, '100022': 1, '100122': 1, '101122': 1, '110022': 2, '110122': 2, '111122': 2}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 1, '100122': 1, '100022': 2, '101022': 1, '110122': 1, '110022': 2, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 1, '100122': 1, '100022': 1, '101022': 1, '110122': 2, '110022': 2, '111022': 2}
#   State coefficients: {'000022': 1, '000122': 2, '001122': 1, '010022': 1, '010122': 2, '011122': 1, '110022': 1, '110122': 2, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 2, '001022': 1, '010122': 1, '010022': 2, '011022': 1, '110122': 1, '110022': 2, '111022': 1}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 2, '010022': 2, '011022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 1, '000122': 1, '000022': 2, '001022': 1, '100122': 1, '100022': 2, '101022': 1}
# Hash: 17ea63f3afb8d81ed79351362be246a84b0d8f1a617532b53cf9c87202e09fe7
#   State coefficients: {'010122': 2, '011022': 1, '011122': 1, '100122': 2, '101022': 1, '101122': 1, '110122': 2, '111022': 1, '111122': 1}
#   State coefficients: {'010022': 1, '010122': 1, '011122': 2, '100022': 1, '100122': 1, '101122': 2, '110022': 1, '110122': 1, '111122': 2}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 1, '100022': 2, '100122': 1, '101122': 1, '110022': 2, '110122': 1, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 2, '011122': 2, '100022': 1, '100122': 1, '101122': 1, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 2, '100122': 1, '100022': 1, '101022': 2, '110122': 1, '110022': 1, '111022': 2}
#   State coefficients: {'010122': 2, '010022': 2, '011022': 2, '100122': 1, '100022': 1, '101022': 1, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'000022': 1, '000122': 1, '001122': 2, '010022': 1, '010122': 1, '011122': 2, '110022': 1, '110122': 1, '111122': 2}
#   State coefficients: {'000022': 2, '000122': 1, '001122': 1, '010022': 2, '010122': 1, '011122': 1, '110022': 2, '110122': 1, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 2, '010122': 1, '010022': 1, '011022': 2, '110122': 1, '110022': 1, '111022': 2}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 1, '010022': 1, '011022': 1, '110122': 2, '110022': 2, '111022': 2}
#   State coefficients: {'000122': 2, '000022': 2, '001022': 2, '010122': 1, '010022': 1, '011022': 1, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 2, '000122': 1, '000022': 1, '001022': 2, '100122': 1, '100022': 1, '101022': 2}
# Hash: 8a2fe1bc23f60bf37abcc30f319e4291291250486f10e1d61835df1468e9e186
#   State coefficients: {'010122': 2, '011022': 1, '011122': 2, '100122': 1, '101022': 1, '101122': 1, '110122': 2, '111022': 1, '111122': 2}
#   State coefficients: {'010022': 1, '010122': 2, '011122': 2, '100022': 1, '100122': 1, '101122': 1, '110022': 1, '110122': 2, '111122': 2}
#   State coefficients: {'010022': 2, '010122': 2, '011122': 1, '100022': 1, '100122': 1, '101122': 1, '110022': 2, '110122': 2, '111122': 1}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 2, '100122': 1, '100022': 1, '101022': 1, '110122': 1, '110022': 2, '111022': 2}
#   State coefficients: {'000022': 1, '000122': 1, '001122': 1, '010022': 1, '010122': 2, '011122': 2, '110022': 1, '110122': 2, '111122': 2}
#   State coefficients: {'000022': 1, '000122': 2, '001122': 2, '010022': 1, '010122': 2, '011122': 2, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'000022': 2, '000122': 2, '001122': 1, '010022': 2, '010122': 2, '011122': 1, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 1, '010022': 2, '011022': 2, '110122': 1, '110022': 2, '111022': 2}
#   State coefficients: {'000122': 1, '000022': 2, '001022': 2, '010122': 1, '010022': 2, '011022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 1, '000122': 1, '000022': 2, '001022': 2, '100122': 1, '100022': 2, '101022': 2}
# Hash: c52695c89755f3473c4476923f54f472d7f851e3729de0f128a75dcf18389d7c
#   State coefficients: {'010122': 2, '011022': 1, '011122': 2, '100122': 2, '101022': 1, '101122': 2, '110122': 1, '111022': 1, '111122': 1}
#   State coefficients: {'010022': 1, '010122': 2, '011122': 2, '100022': 1, '100122': 2, '101122': 2, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 2, '100022': 1, '100122': 1, '101122': 1, '110022': 2, '110122': 1, '111122': 2}
#   State coefficients: {'010022': 2, '010122': 2, '011122': 1, '100022': 2, '100122': 2, '101122': 1, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 2, '100122': 1, '100022': 2, '101022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '100122': 1, '100022': 1, '101022': 1, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'000022': 1, '000122': 2, '001122': 2, '010022': 1, '010122': 1, '011122': 1, '110022': 1, '110122': 2, '111122': 2}
#   State coefficients: {'000022': 2, '000122': 1, '001122': 2, '010022': 2, '010122': 1, '011122': 2, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 2, '001022': 2, '010122': 1, '010022': 1, '011022': 1, '110122': 1, '110022': 2, '111022': 2}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 2, '010022': 1, '011022': 2, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'000122': 2, '000022': 1, '001022': 2, '010122': 2, '010022': 1, '011022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 2, '000122': 1, '000022': 1, '001022': 1, '100122': 1, '100022': 2, '101022': 2}
# Hash: 5c09c39d33c5044b8f46a4634dc032e1ca4fde713d21c8de8e8bb9b12f70ee58
#   State coefficients: {'010122': 2, '011022': 1, '011122': 2, '100122': 2, '101022': 1, '101122': 2, '110122': 2, '111022': 1, '111122': 2}
#   State coefficients: {'010022': 1, '010122': 2, '011122': 2, '100022': 1, '100122': 2, '101122': 2, '110022': 1, '110122': 2, '111122': 2}
#   State coefficients: {'010022': 2, '010122': 2, '011122': 1, '100022': 2, '100122': 2, '101122': 1, '110022': 2, '110122': 2, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 2, '011122': 2, '100022': 1, '100122': 1, '101122': 1, '110022': 2, '110122': 2, '111122': 2}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 2, '100122': 1, '100022': 2, '101022': 2, '110122': 1, '110022': 2, '111022': 2}
#   State coefficients: {'010122': 2, '010022': 2, '011022': 2, '100122': 1, '100022': 1, '101022': 1, '110122': 2, '110022': 2, '111022': 2}
#   State coefficients: {'000022': 1, '000122': 2, '001122': 2, '010022': 1, '010122': 2, '011122': 2, '110022': 1, '110122': 2, '111122': 2}
#   State coefficients: {'000022': 2, '000122': 2, '001122': 1, '010022': 2, '010122': 2, '011122': 1, '110022': 2, '110122': 2, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 2, '001022': 2, '010122': 1, '010022': 2, '011022': 2, '110122': 1, '110022': 2, '111022': 2}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 2, '010022': 2, '011022': 2, '110122': 2, '110022': 2, '111022': 2}
#   State coefficients: {'000122': 2, '000022': 2, '001022': 2, '010122': 2, '010022': 2, '011022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 2, '011022': 2, '000122': 1, '000022': 2, '001022': 2, '100122': 1, '100022': 2, '101022': 2}
# Hash: 73b02aa319212f0ca79f77fdcc58e3641907ff6ee38452af75e9382ee3d156d8
#   State coefficients: {'010122': 1, '011022': 1, '100122': 1, '101022': 1, '110122': 1, '111022': 1}
#   State coefficients: {'010022': 1, '011122': 1, '100022': 1, '101122': 1, '110022': 1, '111122': 1}
#   State coefficients: {'010022': 1, '010122': 1, '011122': 1, '100022': 1, '100122': 1, '101122': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 1, '100122': 1, '100022': 1, '101022': 1}
#   State coefficients: {'000022': 1, '001122': 1, '010022': 1, '011122': 1, '110022': 1, '111122': 1}
#   State coefficients: {'000122': 1, '001022': 1, '010122': 1, '011022': 1, '110122': 1, '111022': 1}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '011022': 1, '000122': 1, '001022': 1, '100122': 1, '101022': 1}
# Hash: 6faa76bf834940c32746804e474bfc33d18f573dfba455f5309420a70ca80fbb
#   State coefficients: {'010122': 2, '011022': 2, '011122': 1, '100122': 2, '101022': 2, '101122': 1, '110122': 1, '111022': 1, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 2, '100022': 2, '100122': 1, '101122': 2, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '100122': 2, '100022': 1, '101022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'000022': 2, '000122': 1, '001122': 2, '010022': 1, '010122': 1, '011122': 1, '110022': 2, '110122': 1, '111122': 2}
#   State coefficients: {'000122': 2, '000022': 1, '001022': 2, '010122': 1, '010022': 1, '011022': 1, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '000122': 1, '000022': 1, '001022': 1, '100122': 2, '100022': 1, '101022': 2}
# Hash: 9e503666fd9112f31f796fb524e9bcd6fa36470b413ea9c1d2d598f0190ae8d2
#   State coefficients: {'010122': 2, '011022': 2, '011122': 1, '100122': 2, '101022': 2, '101122': 1, '110122': 2, '111022': 2, '111122': 1}
#   State coefficients: {'010022': 2, '010122': 1, '011122': 2, '100022': 2, '100122': 1, '101122': 2, '110022': 2, '110122': 1, '111122': 2}
#   State coefficients: {'010022': 2, '010122': 2, '011122': 2, '100022': 2, '100122': 2, '101122': 2, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '100122': 2, '100022': 1, '101022': 2, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'010122': 2, '010022': 2, '011022': 2, '100122': 2, '100022': 2, '101022': 2, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'000022': 2, '000122': 1, '001122': 2, '010022': 2, '010122': 1, '011122': 2, '110022': 2, '110122': 1, '111122': 2}
#   State coefficients: {'000122': 2, '000022': 1, '001022': 2, '010122': 2, '010022': 1, '011022': 2, '110122': 2, '110022': 1, '111022': 2}
#   State coefficients: {'000122': 2, '000022': 2, '001022': 2, '010122': 1, '010022': 1, '011022': 1, '110122': 2, '110022': 2, '111022': 2}
#   State coefficients: {'010122': 2, '010022': 1, '011022': 2, '000122': 2, '000022': 1, '001022': 2, '100122': 2, '100022': 1, '101022': 2}
# Hash: 7e3f2e22887ed60f700e83d6dc47cd94501a3dc45a5c0d818e1a0be2a120429c
#   State coefficients: {'010122': 1, '011022': 1, '011122': 1, '100122': 1, '101022': 1, '101122': 1, '110122': 1, '111022': 1, '111122': 1}
#   State coefficients: {'010022': 1, '010122': 1, '011122': 1, '100022': 1, '100122': 1, '101122': 1, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 1, '100122': 1, '100022': 1, '101022': 1, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'000022': 1, '000122': 1, '001122': 1, '010022': 1, '010122': 1, '011122': 1, '110022': 1, '110122': 1, '111122': 1}
#   State coefficients: {'000122': 1, '000022': 1, '001022': 1, '010122': 1, '010022': 1, '011022': 1, '110122': 1, '110022': 1, '111022': 1}
#   State coefficients: {'010122': 1, '010022': 1, '011022': 1, '000122': 1, '000022': 1, '001022': 1, '100122': 1, '100022': 1, '101022': 1}

# %%
#result_dict
